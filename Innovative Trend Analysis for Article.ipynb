# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
REF= pd.read_excel('ANNUAL.xlsx', sheet_name ='REF')
REF.head()
# Out:
#    YEAR      YEN_FH      YEN_SH       IK_FH       IK_SH      IBN_FH  \
# 0  1981  376.990530  382.342782  382.354498  386.737657  365.637787
# 1  1982  378.615264  382.465169  383.267677  386.968624  366.078667
# 2  1983  379.021151  382.482957  383.826365  387.617333  366.373945
# 3  1984  379.075227  383.212268  384.204444  387.712547  366.794763
# 4  1985  379.485939  383.254908  384.262210  387.854722  366.803010
#
#        IBN_SH      ABJ_FH      ABJ_SH      JAL_FH      JAL_SH      SOK_FH  \
# 0  369.217396  340.399187  340.899959  342.374452  340.126546  311.486194
# 1  370.162702  343.864862  342.780993  342.551850  340.900062  312.795364
# 2  370.447920  344.109408  344.888182  343.144874  344.136353  313.011156
# 3  370.540104  344.494313  345.038192  343.965130  344.303187  313.792615
# 4  370.572805  344.642356  345.171114  344.052530  344.391059  314.267764
#
#        SOK_SH      GOM_FH      GOM_SH      KUK_FH      KUK_SH
# ...

# %%
# Refractivity
fig, axs = plt.subplots(2, 4 , figsize=[20, 10], constrained_layout=True)

def scatter_in_thirds(ax, x, y, colors=('red', 'green', 'blue')):
    n = len(x)
    third = n // 3
    ax.scatter(x[:third], y[:third], color=colors[0], s=100, label='Low values')
    ax.scatter(x[third:2*third], y[third:2*third], color=colors[1], s=100, label='Medium values')
    ax.scatter(x[2*third:], y[2*third:], color=colors[2], s=100, label='High values')

# (a)
scatter_in_thirds(axs[0, 0], REF.YEN_FH, REF.YEN_SH)
axs[0, 0].plot([376, 388], [376, 388], ls='--', c='r')
axs[0, 0].set(xlim=(376, 388), ylim=(376, 388))
axs[0, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].text(386, 377, '(a)', fontsize=20)
axs[0, 0].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[0, 0].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

# (b)
scatter_in_thirds(axs[0, 1], REF.IK_FH, REF.IK_SH)
axs[0, 1].plot([381, 392], [381, 392], ls='--', c='r')
axs[0, 1].set(xlim=(381, 392), ylim=(381, 392))
axs[0, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].text(390, 382, '(b)', fontsize=20)
axs[0, 1].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[0, 1].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

# (c)
scatter_in_thirds(axs[0, 2], REF.IBN_FH, REF.IBN_SH)
axs[0, 2].plot([365, 375], [365, 375], ls='--', c='r')
axs[0, 2].set(xlim=(365, 375), ylim=(365, 375))
axs[0, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].text(374, 366, '(c)', fontsize=20)
axs[0, 2].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[0, 2].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

# (d)
scatter_in_thirds(axs[0, 3], REF.ABJ_FH, REF.ABJ_SH)
axs[0, 3].plot([340, 352], [340, 352], ls='--', c='r')
axs[0, 3].set(xlim=(340, 352), ylim=(340, 352))
axs[0, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].text(350, 342, '(d)', fontsize=20)
axs[0, 3].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[0, 3].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

# (e)
scatter_in_thirds(axs[1, 0], REF.JAL_FH, REF.JAL_SH)
axs[1, 0].plot([340, 353], [340, 353], ls='--', c='r')
axs[1, 0].set(xlim=(340, 353), ylim=(340, 353))
axs[1, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].text(350, 342, '(e)', fontsize=20)
axs[1, 0].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[1, 0].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

# (f)
scatter_in_thirds(axs[1, 1], REF.SOK_FH, REF.SOK_SH)
axs[1, 1].plot([310.5, 336.5], [310.5, 336.5], ls='--', c='r')
axs[1, 1].set(xlim=(310.5, 336.5), ylim=(310.5, 336.5))
axs[1, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].text(333, 315, '(f)', fontsize=20)
axs[1, 1].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[1, 1].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

# (g)
scatter_in_thirds(axs[1, 2], REF.GOM_FH, REF.GOM_SH)
axs[1, 2].plot([320.5, 337], [320.5, 337], ls='--', c='r')
axs[1, 2].set(xlim=(320.5, 337), ylim=(320.5, 337))
axs[1, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].text(335, 323, '(g)', fontsize=20)
axs[1, 2].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[1, 2].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

# (h)
scatter_in_thirds(axs[1, 3], REF.KUK_FH, REF.KUK_SH)
axs[1, 3].plot([299, 319.5], [299, 319.5], ls='--', c='r')
axs[1, 3].set(xlim=(299, 319.5), ylim=(299, 319.5))
axs[1, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].text(314, 303, '(h)', fontsize=20)
axs[1, 3].set_xlabel("Refractivity (N-Units) (1981–2001)", fontsize=15)
axs[1, 3].set_ylabel("Refractivity (N-Units) (2002–2022)", fontsize=15)

plt.legend()
plt.show()

# %%
RH= pd.read_excel('ANNUAL.xlsx', sheet_name ='RH')
RH.head()
# Out:
#    YEAR  YEN_FH  YEN_SH  IK_FH  IK_SH  IBN_FH  IBN_SH  ABJ_FH  ABJ_SH  JAL_FH  \
# 0  1981   85.76   86.67  82.43  84.29   79.70   83.33   64.60   61.63   58.70
# 1  1982   86.08   87.10  82.99  84.98   79.84   83.85   65.59   63.95   60.70
# 2  1983   86.42   87.13  83.28  84.99   82.37   84.65   71.14   64.24   61.62
# 3  1984   86.44   87.23  83.39  85.16   82.43   84.68   72.23   66.79   63.37
# 4  1985   86.58   87.44  83.45  85.30   82.75   85.02   73.21   66.80   63.40
#
#    JAL_SH  SOK_FH  SOK_SH  GOM_FH  GOM_SH  KUK_FH  KUK_SH
# 0   55.61   36.34   39.93   49.05   45.31   28.62   26.77
# 1   57.05   38.17   40.00   49.45   46.30   29.32   27.56
# 2   59.24   38.66   40.07   51.16   47.76   29.50   28.46
# 3   59.57   39.41   40.75   51.44   49.17   29.66   29.88
# 4   60.20   39.71   40.87   52.23   49.41   29.71   30.03

# %%
fig, axs = plt.subplots(2, 4, figsize=[20, 10], constrained_layout=True)

def scatter_in_thirds(ax, x, y, colors=('red', 'green', 'blue')):
    n = len(x)
    third = n // 3
    ax.scatter(x[:third], y[:third], color=colors[0], s=100, label='Low values')
    ax.scatter(x[third:2*third], y[third:2*third], color=colors[1], s=100, label='Medium values')
    ax.scatter(x[2*third:], y[2*third:], color=colors[2], s=100, label='High values')

# (a)
scatter_in_thirds(axs[0, 0], RH.YEN_FH, RH.YEN_SH)
axs[0, 0].plot([85.6, 89.2], [85.6, 89.2], ls='--', c='r')
axs[0, 0].set(xlim=(85.6, 89.2), ylim=(85.6, 89.2))
axs[0, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].text(88.5, 86.3, '(a)', fontsize=20)
axs[0, 0].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[0, 0].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[0, 1], RH.IK_FH, RH.IK_SH )
axs[0, 1].plot([82.2, 87.2], [82.2, 87.2], ls='--', c='r')
axs[0, 1].set(xlim=(82.2, 87.2), ylim=(82.2, 87.2))
axs[0, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].text(86.5, 83, '(b)', fontsize=20)
axs[0, 1].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[0, 1].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[0, 2], RH.IBN_FH, RH.IBN_SH)
axs[0, 2].plot([79.5, 87], [79.5, 87], ls='--', c='r')
axs[0, 2].set(xlim=(79.5, 87), ylim=(79.5, 87))
axs[0, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].text(86, 81, '(c)', fontsize=20)
axs[0, 2].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[0, 2].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[0, 3], RH.ABJ_FH, RH.ABJ_SH)
axs[0, 3].plot([61.5, 78.5], [61.5, 78.5], ls='--', c='r')
axs[0, 3].set(xlim=(61.5, 78.5), ylim=(61.5, 78.5))
axs[0, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].text(75, 65, '(d)', fontsize=20)
axs[0, 3].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[0, 3].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 0], RH.JAL_FH, RH.JAL_SH)
axs[1, 0].plot([55.5, 74.2], [55.5, 74.2], ls='--', c='r')
axs[1, 0].set(xlim=(55.5, 74.2), ylim=(55.5, 74.2))
axs[1, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].text(71, 59, '(e)', fontsize=20)
axs[1, 0].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[1, 0].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 1], RH.SOK_FH, RH.SOK_SH)
axs[1, 1].plot([36, 56], [36, 56], ls='--', c='r')
axs[1, 1].set(xlim=(36, 56), ylim=(36, 56))
axs[1, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].text(52, 40, '(f)', fontsize=20)
axs[1, 1].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[1, 1].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 2], RH.GOM_FH, RH.GOM_SH)
axs[1, 2].plot([45, 63], [45, 63], ls='--', c='r')
axs[1, 2].set(xlim=(45, 63), ylim=(45, 63))
axs[1, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].text(60, 48, '(g)', fontsize=20)
axs[1, 2].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[1, 2].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 3], RH.KUK_FH, RH.KUK_SH)
axs[1, 3].plot([26.5, 40.5], [26.5, 40.5], ls='--', c='r')
axs[1, 3].set(xlim=(26.5, 40.5), ylim=(26.5, 40.5))
axs[1, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].text(38, 29, '(h)', fontsize=20)
axs[1, 3].set_xlabel("Relative Humidity(%) (1981-2001)", fontsize=15)
axs[1, 3].set_ylabel("Relative Humidity(%) (2002-2022)", fontsize=15)

#plt.subplot_tool()
plt.legend()
plt.show()
#fig.savefig('VEG_PRESSURE.png', dpi = 300)

# %%
PRES= pd.read_excel('ANNUAL.xlsx', sheet_name ='PRES')
PRES.head()
# Out:
#    YEAR  YEN_FH  YEN_SH   IK_FH   IK_SH  IBN_FH  IBN_SH  ABJ_FH  ABJ_SH  \
# 0  1981  1008.5  1008.5  1009.5  1009.5   988.9   989.0   964.0   964.3
# 1  1982  1008.6  1008.6  1009.6  1009.5   989.0   989.0   964.2   964.3
# 2  1983  1008.7  1008.7  1009.6  1009.7   989.1   989.2   964.3   964.3
# 3  1984  1008.8  1008.8  1009.8  1009.7   989.1   989.2   964.5   964.4
# 4  1985  1008.9  1008.8  1009.9  1009.7   989.3   989.2   964.5   964.5
#
#    JAL_FH  JAL_SH  SOK_FH  SOK_SH  GOM_FH  GOM_SH  KUK_FH  KUK_SH
# 0   980.7   981.0   978.0   978.3   966.3   966.5   976.3   976.6
# 1   981.0   981.0   978.2   978.4   966.3   966.6   976.5   976.7
# 2   981.1   981.0   978.2   978.4   966.6   966.6   976.5   976.8
# 3   981.2   981.1   978.4   978.5   966.7   966.7   976.7   976.8
# 4   981.2   981.2   978.5   978.5   966.7   966.7   976.8   976.9

# %%
fig, axs = plt.subplots(2, 4, figsize=[20, 10], constrained_layout=True)

def scatter_in_thirds(ax, x, y, colors=('red', 'green', 'blue')):
    n = len(x)
    third = n // 3
    ax.scatter(x[:third], y[:third], color=colors[0], s=100, label='Low values')
    ax.scatter(x[third:2*third], y[third:2*third], color=colors[1], s=100, label='Medium values')
    ax.scatter(x[2*third:], y[2*third:], color=colors[2], s=100, label='High values')

# (a)
scatter_in_thirds(axs[0, 0], PRES.YEN_FH, PRES.YEN_SH)
axs[0, 0].plot([1008.4, 1009.9], [1008.4, 1009.9], ls='--', c='r')
axs[0, 0].set(xlim=(1008.4, 1009.9), ylim=(1008.4, 1009.9))
axs[0, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].text(1009.6, 1008.6, '(a)', fontsize=20)
axs[0, 0].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[0, 0].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[0, 1], PRES.IK_FH, PRES.IK_SH)
axs[0, 1].plot([1009.4, 1010.8], [1009.4, 1010.8], ls='--', c='r')
axs[0, 1].set(xlim=(1009.4, 1010.8), ylim=(1009.4, 1010.8))
axs[0, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].text(1010.5, 1009.6, '(b)', fontsize=20)
axs[0, 1].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[0, 1].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[0, 2], PRES.IBN_FH, PRES.IBN_SH)
axs[0, 2].plot([988.8, 990.2], [988.8, 990.2], ls='--', c='r')
axs[0, 2].set(xlim=(988.8, 990.2), ylim=(988.8, 990.2))
axs[0, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].text(990, 989, '(c)', fontsize=20)
axs[0, 2].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[0, 2].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[0, 3], PRES.ABJ_FH, PRES.ABJ_SH)
axs[0, 3].plot([963.9, 965.4], [963.9, 965.4], ls='--', c='r')
axs[0, 3].set(xlim=(963.9, 965.4), ylim=(963.9, 965.4))
axs[0, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].text(965.1, 964.2, '(d)', fontsize=20)
axs[0, 3].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[0, 3].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 0], PRES.JAL_FH, PRES.JAL_SH)
axs[1, 0].plot([980.6, 982.3], [980.6, 982.3], ls='--', c='r')
axs[1, 0].set(xlim=(980.6, 982.3), ylim=(980.6, 982.3))
axs[1, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].text(982, 981, '(e)', fontsize=20)
axs[1, 0].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[1, 0].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 1], PRES.SOK_FH, PRES.SOK_SH)
axs[1, 1].plot([977.9, 980], [977.9, 980], ls='--', c='r')
axs[1, 1].set(xlim=(977.9, 980), ylim=(977.9, 980))
axs[1, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].text(979.6, 978.4, '(f)', fontsize=20)
axs[1, 1].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[1, 1].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 2], PRES.GOM_FH, PRES.GOM_SH)
axs[1, 2].plot([966.2, 968], [966.2, 968], ls='--', c='r')
axs[1, 2].set(xlim=(966.2, 968), ylim=(966.2, 968))
axs[1, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].text(967.7, 966.4, '(g)', fontsize=20)
axs[1, 2].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[1, 2].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 3], PRES.KUK_FH, PRES.KUK_SH)
axs[1, 3].plot([976.2, 978.4], [976.2, 978.4], ls='--', c='r')
axs[1, 3].set(xlim=(976.2, 978.4), ylim=(976.2, 978.4))
axs[1, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].text(978, 976.5, '(h)', fontsize=20)
axs[1, 3].set_xlabel("Atmospheric Pressure (hPa) (1981-2001)", fontsize=15)
axs[1, 3].set_ylabel("Atmospheric Pressure (hPa) (2002-2022)", fontsize=15)

#plt.subplot_tool()
plt.legend()
plt.show()

# %%
TEMP= pd.read_excel('ANNUAL.xlsx', sheet_name ='TEMP1')
TEMP.head()
# Out:
#    YEAR  YEN_FH  YEN_SH  IK_FH  IK_SH  IBN_FH  IBN_SH  ABJ_FH  ABJ_SH  JAL_FH  \
# 0  1981   25.09    25.7  26.46  26.90   24.50   24.75   23.71   24.63   24.39
# 1  1982   25.22    25.7  26.60  27.05   24.58   24.86   23.75   24.66   24.73
# 2  1983   25.23    25.7  26.90  27.07   24.62   24.89   23.87   24.97   25.07
# 3  1984   25.26    25.7  26.90  27.08   24.80   24.92   23.92   25.28   25.30
# 4  1985   25.29    25.7  26.92  27.14   24.82   24.96   23.93   25.42   25.38
#
#    JAL_SH  SOK_FH  SOK_SH  GOM_FH  GOM_SH  KUK_FH  KUK_SH
# 0   26.21   27.64   26.26   25.49   24.87   29.75   29.58
# 1   26.62   27.66   26.60   25.84   25.56   30.19   29.82
# 2   26.68   27.68   27.14   25.93   26.21   30.21   30.29
# 3   26.81   27.95   27.72   25.98   26.82   30.46   30.33
# 4   26.82   28.11   27.86   26.03   26.85   30.55   30.65

# %%
fig, axs = plt.subplots(2, 4, figsize=[20, 10], constrained_layout=True)

def scatter_in_thirds(ax, x, y, colors=('red', 'green', 'blue')):
    n = len(x)
    third = n // 3
    ax.scatter(x[:third], y[:third], color=colors[0], s=100, label='Low values')
    ax.scatter(x[third:2*third], y[third:2*third], color=colors[1], s=100, label='Medium values')
    ax.scatter(x[2*third:], y[2*third:], color=colors[2], s=100, label='High values')

# (a)
scatter_in_thirds(axs[0, 0], TEMP.YEN_FH, TEMP.YEN_SH)
axs[0, 0].plot([25, 26.3], [25, 26.3], ls='--', c='r')
axs[0, 0].set(xlim=(25, 26.3), ylim=(25, 26.3))
axs[0, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].text(26, 25.2, '(a)', fontsize=20)
axs[0, 0].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[0, 0].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[0, 1], TEMP.IK_FH, TEMP.IK_SH)
axs[0, 1].plot([26.4, 27.9], [26.4, 27.9], ls='--', c='r')
axs[0, 1].set(xlim=(26.4, 27.9), ylim=(26.4, 27.9))
axs[0, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].text(27.6, 26.7, '(b)', fontsize=20)
axs[0, 1].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[0, 1].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[0, 2], TEMP.IBN_FH, TEMP.IBN_SH)
axs[0, 2].plot([24.4, 25.9], [24.4, 25.9], ls='--', c='r')
axs[0, 2].set(xlim=(24.4, 25.9), ylim=(24.4, 25.9))
axs[0, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].text(25.6, 24.7, '(c)', fontsize=20)
axs[0, 2].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[0, 2].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[0, 3], TEMP.ABJ_FH, TEMP.ABJ_SH)
axs[0, 3].plot([23.65, 27.5], [23.65, 27.5], ls='--', c='r')
axs[0, 3].set(xlim=(23.65, 27.5), ylim=(23.65, 27.5))
axs[0, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].text(26.5, 24.5, '(d)', fontsize=20)
axs[0, 3].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[0, 3].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 0], TEMP.JAL_FH, TEMP.JAL_SH)
axs[1, 0].plot([24.35, 28.5], [24.35, 28.5], ls='--', c='r')
axs[1, 0].set(xlim=(24.35, 28.5), ylim=(24.35, 28.5))
axs[1, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].text(27.5, 25, '(e)', fontsize=20)
axs[1, 0].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[1, 0].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 1], TEMP.SOK_FH, TEMP.SOK_SH)
axs[1, 1].plot([26.2, 29.6], [26.2, 29.6], ls='--', c='r')
axs[1, 1].set(xlim=(26.2, 29.6), ylim=(26.2, 29.6))
axs[1, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].text(29, 26.8, '(f)', fontsize=20)
axs[1, 1].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[1, 1].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 2], TEMP.GOM_FH, TEMP.GOM_SH)
axs[1, 2].plot([24.8, 28.8], [24.8, 28.8], ls='--', c='r')
axs[1, 2].set(xlim=(24.8, 28.8), ylim=(24.8, 28.8))
axs[1, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].text(28, 25.5, '(g)', fontsize=20)
axs[1, 2].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[1, 2].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 3], TEMP.KUK_FH, TEMP.KUK_SH)
axs[1, 3].plot([29.5, 32.4], [29.5, 32.4], ls='--', c='r')
axs[1, 3].set(xlim=(29.5, 32.4), ylim=(29.5, 32.4))
axs[1, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].text(31.5, 30, '(h)', fontsize=20)
axs[1, 3].set_xlabel("Temperature($^oC$) (1981-2001)", fontsize=15)
axs[1, 3].set_ylabel("Temperature($^oC$) (2002-2022)", fontsize=15)

#plt.subplot_tool()
plt.legend()
plt.show()
#fig.savefig('VEG_PRESSURE.png', dpi = 300)

# %%
PRECIP= pd.read_excel('ANNUAL.xlsx', sheet_name ='PRECIP')
PRECIP.head()
# Out:
#    YEAR   YEN_FH   YEN_SH    IK_FH    IK_SH   IBN_FH   IBN_SH   ABJ_FH  \
# 0  1981  1446.37  1330.39  1618.76  1439.60  1073.38  1117.21   528.30
# 1  1982  1776.67  1559.47  1644.08  1706.69  1209.86  1329.86   992.62
# 2  1983  1802.96  1688.83  1680.53  1851.75  1334.73  1407.80  1327.07
# 3  1984  1998.07  1748.94  1890.43  1968.82  1406.38  1449.19  1467.65
# 4  1985  2105.43  1916.87  1967.77  2027.04  1431.32  1545.68  1510.46
#
#     ABJ_SH   JAL_FH  JAL_SH  SOK_FH  SOK_SH  GOM_FH  GOM_SH  KUK_FH  KUK_SH
# 0   787.32   674.83  623.76  409.04  495.38  662.69  583.33  239.79  269.71
# 1   810.73   941.07  741.56  409.77  522.72  736.67  611.75  268.39  278.22
# 2   832.35   954.56  833.83  472.52  547.91  749.11  672.50  279.66  307.06
# 3   852.07   970.85  839.36  472.73  568.10  803.06  688.68  282.19  347.42
# 4  1015.46  1022.12  843.92  490.45  578.31  830.19  719.29  289.41  355.72

# %%
fig, axs = plt.subplots(2, 4, figsize=[20, 10], constrained_layout=True)

def scatter_in_thirds(ax, x, y, colors=('red', 'green', 'blue')):
    n = len(x)
    third = n // 3
    ax.scatter(x[:third], y[:third], color=colors[0], s=100, label='Low values')
    ax.scatter(x[third:2*third], y[third:2*third], color=colors[1], s=100, label='Medium values')
    ax.scatter(x[2*third:], y[2*third:], color=colors[2], s=100, label='High values')

# (a)
scatter_in_thirds(axs[0, 0], PRECIP.YEN_FH, PRECIP.YEN_SH)
axs[0, 0].plot([1310, 5615], [1310, 5615], ls='--', c='r')
axs[0, 0].set(xlim=(1310, 5615), ylim=(1310, 5615))
axs[0, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 0].text(4600, 2000, '(a)', fontsize=20)
axs[0, 0].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[0, 0].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[0, 1], PRECIP.IK_FH, PRECIP.IK_SH)
axs[0, 1].plot([1430, 5505], [1430, 5505], ls='--', c='r')
axs[0, 1].set(xlim=(1430, 5505), ylim=(1430, 5505))
axs[0, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 1].text(4600, 2000, '(b)', fontsize=20)
axs[0, 1].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[0, 1].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[0, 2], PRECIP.IBN_FH, PRECIP.IBN_SH)
axs[0, 2].plot([1065, 2415], [1065, 2415], ls='--', c='r')
axs[0, 2].set(xlim=(1065, 2415), ylim=(1065, 2415))
axs[0, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 2].text(2100, 1400, '(c)', fontsize=20)
axs[0, 2].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[0, 2].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[0, 3], PRECIP.ABJ_FH, PRECIP.ABJ_SH)
axs[0, 3].plot([520, 2230], [520, 2230], ls='--', c='r')
axs[0, 3].set(xlim=(520, 2230), ylim=(520, 2230))
axs[0, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[0, 3].text(1900, 800, '(d)', fontsize=20)
axs[0, 3].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[0, 3].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 0], PRECIP.JAL_FH, PRECIP.JAL_SH)
axs[1, 0].plot([615, 1825], [615, 1825], ls='--', c='r')
axs[1, 0].set(xlim=(615, 1825), ylim=(615, 1825))
axs[1, 0].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 0].text(1600, 800, '(e)', fontsize=20)
axs[1, 0].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[1, 0].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)


scatter_in_thirds(axs[1, 1], PRECIP.SOK_FH, PRECIP.SOK_SH)
axs[1, 1].plot([400, 1260], [400, 1260], ls='--', c='r')
axs[1, 1].set(xlim=(400, 1260), ylim=(400, 1260))
axs[1, 1].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 1].text(1100, 500, '(f)', fontsize=20)
axs[1, 1].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[1, 1].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 2], PRECIP.GOM_FH, PRECIP.GOM_SH)
axs[1, 2].plot([570, 2545], [570, 2545], ls='--', c='r')
axs[1, 2].set(xlim=(570, 2545), ylim=(570, 2545))
axs[1, 2].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 2].text(2200, 900, '(g)', fontsize=20)
axs[1, 2].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[1, 2].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)

scatter_in_thirds(axs[1, 3], PRECIP.KUK_FH, PRECIP.KUK_SH)
axs[1, 3].plot([230, 800], [230, 800], ls='--', c='r')
axs[1, 3].set(xlim=(230, 800), ylim=(230, 800))
axs[1, 3].xaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].yaxis.set_major_locator(plt.MaxNLocator(3))
axs[1, 3].text(700, 350, '(h)', fontsize=20)
axs[1, 3].set_xlabel("Precipiatation (mm) (1981-2001)", fontsize=15)
axs[1, 3].set_ylabel("Precipiatation (mm) (2002-2022)", fontsize=15)

plt.legend()
plt.show()
